# %%
# !ls
# Out:
# Test_1Freq3  Test_2Freq13  Test_4Freq1365  Test_6Freq135679  Untitled.ipynb

# %%
import scipy
import matplotlib.pyplot as plt
from numpy.fft import fft , fftfreq , ifft , fftshift
import scipy.fftpack as syfp
import numpy as np
Fs = 64000
t= np.arange(0,1,1/Fs)
n = np.size(t)
fr_positive = (Fs/2)*np.linspace(0,1,n//2)

fr = (Fs/2)*np.linspace(0,1,n//2) 

f = scipy.fromfile(open("Test_6Freq135679"), dtype=scipy.float32)
x_fft =fft(f)
# Out:
# /home/jax/.local/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: scipy.fromfile is deprecated and will be removed in SciPy 2.0.0, use numpy.fromfile instead
#   del sys.path[0]

# %%
fft_fr = syfp.fftfreq(len(f),1/Fs)
plt.subplot (2,1,2)
plt.plot(fft_fr,abs(x_fft))
plt.tight_layout()

# %%
Fs = 64000
t = np.arange(0,0.01,1/Fs) 
plt.subplot (2,1,2)
plt.plot(t,f[0:640])

# %%
import scipy
import matplotlib.pyplot as plt
from numpy.fft import fft , fftfreq , ifft , fftshift
import scipy.fftpack as syfp
import numpy as np
Fs = 64000
t= np.arange(0,1,1/Fs)
n = np.size(t)
fr_positive = (Fs/2)*np.linspace(0,1,n//2)

fr = (Fs/2)*np.linspace(0,1,n//2) 

f_13 = scipy.fromfile(open("Test_2Freq13"), dtype=scipy.float32)
x_fft_13 =fft(f_13)
# Out:
# /home/jax/.local/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: scipy.fromfile is deprecated and will be removed in SciPy 2.0.0, use numpy.fromfile instead
#   del sys.path[0]

# %%
fft_fr_13 = syfp.fftfreq(len(f_13),1/Fs)
plt.subplot (2,1,2)
plt.plot(fft_fr_13,abs(x_fft_13))
plt.tight_layout()

# %%
Fs = 64000
t = np.arange(0,0.01,1/Fs) 
plt.subplot (2,1,2)
plt.plot(t,f_13[0:640])
